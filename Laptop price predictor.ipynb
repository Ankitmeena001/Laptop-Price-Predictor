# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('laptop_data.csv')

# %%
df=df.drop('Unnamed: 0',axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   object
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   object
#  10  Price             1303 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 112.1+ KB

# %%
df['Ram'] = df['Ram'].str.replace('GB','')
df['Weight'] = df['Weight'].str.replace('kg','')

# %%
df['Ram'] = df['Ram'].astype('int32')
df['Weight'] = df['Weight'].astype('float32')

# %%
import seaborn as sns
sns.distplot(df['Price'])
# Out:
# C:\Users\ankit\AppData\Local\Temp\ipykernel_27872\2229499591.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
sns.barplot(x=df['Company'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TypeName'>

# %%
sns.barplot(x=df['TypeName'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df['Inches'])
# Out:
# C:\Users\ankit\AppData\Local\Temp\ipykernel_27872\1439577752.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Inches'])
# <Axes: xlabel='Inches', ylabel='Density'>

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080

# %%
sns.scatterplot(x=df['Inches'],y=df['Price'])
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# IPS Panel Touchscreen 2560x1440                    5
# IPS Panel Retina Display 2880x1800                 4
# IPS Panel Touchscreen 1920x1200                    4
# 1440x900                                           4
# IPS Panel 2560x1440                                4
# IPS Panel Quad HD+ 2560x1440                       3
# Quad HD+ 3200x1800                                 3
# 1920x1080                                          3
# Touchscreen 2400x1600                              3
# 2560x1440                                          3
# IPS Panel Touchscreen 1366x768                     3
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# IPS Panel Full HD 2160x1440                        2
# IPS Panel Quad HD+ 3200x1800                       2
# IPS Panel Retina Display 2736x1824                 1
# IPS Panel Full HD 1920x1200                        1
# IPS Panel Full HD 2560x1440                        1
# IPS Panel Full HD 1366x768                         1
# Touchscreen / Full HD 1920x1080                    1
# Touchscreen / Quad HD+ 3200x1800                   1
# Touchscreen / 4K Ultra HD 3840x2160                1
# IPS Panel Touchscreen 2400x1600                    1
# Name: count, dtype: int64

# %%
df['Touchscreen'] = df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
df.sample(15)
# Out:
#       Company            TypeName  Inches  \
# 656      Dell            Notebook    15.6
# 413      Acer  2 in 1 Convertible    13.3
# 639      Dell            Notebook    15.6
# 732        HP            Notebook    15.6
# 1284   Lenovo  2 in 1 Convertible    14.0
# 762    Google           Ultrabook    12.3
# 143   Toshiba            Notebook    15.6
# 1142       HP  2 in 1 Convertible    13.3
# 466      Acer            Notebook    15.6
# 1236       HP           Ultrabook    14.0
# 147      Asus            Notebook    15.6
# 810        HP              Gaming    17.3
# 1231    Razer              Gaming    14.0
# 433    Lenovo         Workstation    15.6
# 1129       HP              Gaming    17.3
#
#                                ScreenResolution  \
# 656                           Full HD 1920x1080
# 413   IPS Panel Full HD / Touchscreen 1920x1080
# 639         4K Ultra HD / Touchscreen 3840x2160
# 732                           Full HD 1920x1080
# 1284  IPS Panel Full HD / Touchscreen 1920x1080
# 762                       Touchscreen 2400x1600
# 143                                    1366x768
# 1142            Full HD / Touchscreen 1920x1080
# 466                                    1366x768
# 1236                                  2560x1440
# 147                           Full HD 1920x1080
# 810                 IPS Panel Full HD 1920x1080
# 1231                          Full HD 1920x1080
# 433             IPS Panel 4K Ultra HD 3840x2160
# 1129                IPS Panel Full HD 1920x1080
#
#                                        Cpu  Ram                Memory  \
# 656             Intel Core i7 8550U 1.8GHz    8             256GB SSD
# 413             Intel Core i7 6500U 2.5GHz    8             256GB SSD
# 639            Intel Core i7 7700HQ 2.8GHz   16               1TB SSD
# 732             AMD A9-Series A9-9420 3GHz    6  128GB SSD +  1TB HDD
# 1284            Intel Core i7 6500U 2.5GHz    4             128GB SSD
# 762              Intel Core i5 7Y57 1.2GHz    8             256GB SSD
# 143             Intel Core i5 6200U 2.3GHz    4             500GB HDD
# 1142            Intel Core i5 6300U 2.4GHz    8             256GB SSD
# 466               Intel Core i3 6006U 2GHz    4             500GB HDD
# 1236            Intel Core i7 6500U 2.5GHz    8             256GB SSD
# 147   Intel Celeron Dual Core N3350 1.1GHz    4               1TB HDD
# 810            Intel Core i7 7700HQ 2.8GHz   12               1TB HDD
# 1231           Intel Core i7 7700HQ 2.8GHz   16               1TB SSD
# 433             Intel Core i7 7600U 2.8GHz   16             512GB SSD
# 1129           Intel Core i5 6300HQ 2.3GHz    8  128GB SSD +  1TB HDD
#
#                            Gpu       OpSys  Weight        Price  Touchscreen
# 656             AMD Radeon 530  Windows 10    2.20   48964.3200            0
# 413      Intel HD Graphics 520  Windows 10    1.60   42038.4528            1
# 639    Nvidia GeForce GTX 1050  Windows 10    2.06  127818.7200            1
# 732             AMD Radeon 520  Windows 10    2.10   34632.0000            0
# 1284     Intel HD Graphics 520  Windows 10    1.80   33992.6400            1
# 762      Intel HD Graphics 615   Chrome OS    1.10   83063.5200            1
# 143      Intel HD Graphics 520  Windows 10    2.10   32074.5600            0
# 1142     Intel HD Graphics 520  Windows 10    1.48   86793.1200            1
# 466   Nvidia GeForce GTX 940MX  Windows 10    2.20   24988.3200            0
# 1236     Intel HD Graphics 520   Windows 7    1.54  117119.5632            0
# 147      Intel HD Graphics 500  Windows 10    2.00   18328.3200            0
# 810          AMD Radeon RX 580  Windows 10    3.74   93186.7200            0
# 1231   Nvidia GeForce GTX 1060  Windows 10    1.95  186426.7200            0
# 433       Nvidia GeForce 940MX  Windows 10    2.30  130269.6000            0
# 1129   Nvidia GeForce GTX 1060  Windows 10    3.35   60153.1200            0

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Touchscreen'>

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price'])
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %%
df['Ips'] = df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
df['Ips'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Ips'>

# %%
sns.barplot(x=df['Ips'],y=df['Price'])
# Out:
# <Axes: xlabel='Ips', ylabel='Price'>

# %%
new = df['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
df['Width'] = new[0].str.extract('(\d+)').astype(int)   # extracts 1920, 1366, etc.
df['Height'] = new[1].astype(int)                       # directly convert right side
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\ankit\AppData\Local\Temp\ipykernel_27872\3527818956.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df['Width'] = new[0].str.extract('(\d+)').astype(int)   # extracts 1920, 1366, etc.

# %%
df.sample(15)
# Out:
#      Company            TypeName  Inches                 ScreenResolution  \
# 107     Asus           Ultrabook    14.0      IPS Panel Full HD 1920x1080
# 500     Asus             Netbook    11.6                         1366x768
# 854     Asus            Notebook    15.6      IPS Panel Full HD 1920x1080
# 663       HP            Notebook    15.6                        1920x1080
# 519     Asus              Gaming    17.3                Full HD 1920x1080
# 1206      HP            Notebook    15.6                         1366x768
# 784   Lenovo           Ultrabook    14.0                Full HD 1920x1080
# 1160  Lenovo           Ultrabook    14.0                Full HD 1920x1080
# 255     Dell           Ultrabook    13.3                Full HD 1920x1080
# 1236      HP           Ultrabook    14.0                        2560x1440
# 532     Asus            Notebook    15.6  IPS Panel 4K Ultra HD 3840x2160
# 1072      HP           Ultrabook    12.5                Full HD 1920x1080
# 126       HP            Notebook    14.0                Full HD 1920x1080
# 101       HP            Notebook    15.6                Full HD 1920x1080
# 880       HP  2 in 1 Convertible    13.3  Full HD / Touchscreen 1920x1080
#
#                                        Cpu  Ram                Memory  \
# 107             Intel Core i7 7500U 2.7GHz    8             256GB SSD
# 500   Intel Celeron Dual Core N3350 1.1GHz    4    64GB Flash Storage
# 854             Intel Core i7 7500U 2.7GHz    8             256GB SSD
# 663               Intel Core i3 6006U 2GHz    6               1TB HDD
# 519            Intel Core i7 7700HQ 2.8GHz   16  256GB SSD +  1TB HDD
# 1206            Intel Core i5 7200U 2.5GHz    8             256GB SSD
# 784             Intel Core i7 7500U 2.7GHz   16             512GB SSD
# 1160            Intel Core i7 6600U 2.6GHz    8             256GB SSD
# 255             Intel Core i5 8250U 1.6GHz    8             256GB SSD
# 1236            Intel Core i7 6500U 2.5GHz    8             256GB SSD
# 532             Intel Core i7 7500U 2.7GHz    8  256GB SSD +  1TB HDD
# 1072            Intel Core i5 6200U 2.3GHz    8             256GB SSD
# 126             Intel Core i5 8250U 1.6GHz    8               1TB HDD
# 101           AMD E-Series E2-9000e 1.5GHz    4             500GB HDD
# 880             Intel Core i5 7200U 2.5GHz    4             256GB SSD
#
#                             Gpu         OpSys  Weight        Price  \
# 107        Nvidia GeForce 940MX    Windows 10    1.30   63563.0400
# 500       Intel HD Graphics 500  Windows 10 S    1.20   18115.2000
# 854    Nvidia GeForce GTX 930MX    Windows 10    2.30   41931.3600
# 663          AMD Radeon R5 M430    Windows 10    2.04   28717.9200
# 519   Nvidia GeForce GTX1050 Ti    Windows 10    3.00   80133.1200
# 1206      Intel HD Graphics 620    Windows 10    1.91   30849.1200
# 784       Intel HD Graphics 620    Windows 10    1.70  122490.7200
# 1160      Intel HD Graphics 520     Windows 7    1.70   79866.7200
# 255      Intel UHD Graphics 620    Windows 10    1.41   50562.7200
# 1236      Intel HD Graphics 520     Windows 7    1.54  117119.5632
# 532     Nvidia GeForce GTX 960M    Windows 10    2.00   69210.7200
# 1072      Intel HD Graphics 520     Windows 7    1.26   63882.7200
# 126      Intel UHD Graphics 620    Windows 10    1.63   43263.3600
# 101               AMD Radeon R2    Windows 10    2.10   18594.7200
# 880       Intel HD Graphics 620    Windows 10    1.28   90576.0000
#
#       Touchscreen  Ips  Width  Height
# 107             0    1   1920    1080
# 500             0    0   1366     768
# 854             0    1   1920    1080
# 663             0    0   1920    1080
# 519             0    0   1920    1080
# 1206            0    0   1366     768
# 784             0    0   1920    1080
# 1160            0    0   1920    1080
# 255             0    0   1920    1080
# 1236            0    0   2560    1440
# 532             0    1      4    2160
# 1072            0    0   1920    1080
# 126             0    0   1920    1080
# 101             0    0   1920    1080
# 880             1    0   1920    1080

# %%
df['X_res'] = new[0]
df['Y_res'] = new[1]

# %%
df['X_res'] = df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df=df.drop('Height',axis=1)

# %%
df['X_res'] = df['X_res'].astype('int')
df['Y_res'] = df['Y_res'].astype('int')

# %%
df.select_dtypes(include='number').corr()['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# Ips            0.252208
# Width          0.083832
# X_res          0.556529
# Y_res          0.552809
# Name: Price, dtype: float64

# %%
df['ppi'] = (((df['X_res']**2) + (df['Y_res']**2))**0.5/df['Inches']).astype('float')

# %%
df.drop(columns=['ScreenResolution'],inplace=True)

# %%
df.drop(columns=['Inches','X_res','Y_res'],inplace=True)

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: count, Length: 118, dtype: int64

# %%
df['Cpu Name'] = df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.sample(15)
# Out:
#       Company            TypeName                                   Cpu  Ram  \
# 855      Dell            Notebook            Intel Core i5 7200U 2.5GHz    8
# 982    Lenovo            Notebook           AMD A12-Series 9720P 3.6GHz    6
# 497        HP            Notebook            Intel Core i7 7600U 2.8GHz    8
# 1186     Dell  2 in 1 Convertible            Intel Core i7 7500U 2.7GHz   16
# 752      Asus            Notebook           Intel Core i5 6300HQ 2.3GHz    4
# 1014       HP            Notebook            Intel Core i3 7100U 2.4GHz    4
# 1034       HP            Notebook            Intel Core i7 6500U 2.5GHz    8
# 203    Lenovo              Gaming           Intel Core i7 7700HQ 2.8GHz   16
# 517      Asus              Gaming           Intel Core i7 7700HQ 2.8GHz   24
# 159   Toshiba            Notebook            Intel Core i3 6006U 2.2GHz    4
# 897        HP            Notebook            Intel Core i7 7500U 2.7GHz    8
# 305    Lenovo            Notebook  Intel Pentium Quad Core N4200 1.1GHz    4
# 1152   Lenovo            Notebook            Intel Core i5 6200U 2.3GHz    8
# 1296       HP             Netbook  Intel Celeron Dual Core N3060 1.6GHz    2
# 1245     Asus              Gaming           Intel Core i7 7700HQ 2.8GHz   16
#
#                     Memory                         Gpu       OpSys  Weight  \
# 855              128GB SSD       Intel HD Graphics 620  Windows 10    1.90
# 982              256GB SSD              AMD Radeon 530  Windows 10    2.20
# 497                1TB SSD       Intel HD Graphics 620  Windows 10    1.48
# 1186             512GB SSD       Intel HD Graphics 620  Windows 10    2.09
# 752                1TB HDD     Nvidia GeForce GTX 950M       No OS    2.45
# 1014             500GB HDD       Intel HD Graphics 620  Windows 10    1.49
# 1034             256GB SSD       Intel HD Graphics 520  Windows 10    1.84
# 203   512GB SSD +  1TB HDD     Nvidia GeForce GTX 1060  Windows 10    3.20
# 517              512GB SSD      Nvidia GeForce GTX1080  Windows 10    2.24
# 159              500GB HDD       Intel HD Graphics 520  Windows 10    2.10
# 897                1TB HDD        Nvidia GeForce 930MX  Windows 10    2.04
# 305                1TB HDD       Intel HD Graphics 505       No OS    2.20
# 1152               1TB HDD          AMD Radeon R5 M330       No OS    2.32
# 1296    32GB Flash Storage       Intel HD Graphics 400  Windows 10    1.17
# 1245  256GB SSD +  1TB HDD  Nvidia GeForce GTX 1050 Ti  Windows 10    2.50
#
#             Price  Touchscreen  Ips  Width         ppi              Cpu Name
# 855    50349.6000            0    0   1920  141.211998         Intel Core i5
# 982    29250.7200            0    0   1920  141.211998  AMD A12-Series 9720P
# 497    93186.7200            0    0   1920  157.350512         Intel Core i7
# 1186   62817.1200            1    0   1920  141.211998         Intel Core i7
# 752    30849.1200            0    0   1366  100.454670         Intel Core i5
# 1014   42624.0000            0    0   1366  117.826530         Intel Core i3
# 1034   65480.5872            0    0   1920  141.211998         Intel Core i7
# 203    93186.7200            0    1   1920  141.211998         Intel Core i7
# 517   158135.0400            0    0   1920  141.211998         Intel Core i7
# 159    23816.1600            0    0   1366  100.454670         Intel Core i3
# 897    47952.0000            0    0   1920  141.211998         Intel Core i7
# 305    19180.2672            0    0   1366  100.454670    Intel Pentium Quad
# 1152   31914.7200            0    0   1920  141.211998         Intel Core i5
# 1296   11135.5200            0    0   1366  135.094211    Intel Celeron Dual
# 1245   85248.0000            0    1   1920  141.211998         Intel Core i7

# %%
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['Cpu brand'] = df['Cpu Name'].apply(fetch_processor)

# %%
df['Cpu brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cpu brand'>

# %%
sns.barplot(x=df['Cpu brand'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Cpu','Cpu Name'],inplace=True)

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Ram'>

# %%
sns.barplot(x=df['Ram'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 512GB SSD +  256GB SSD             1
# 512GB SSD +  512GB SSD             1
# 64GB Flash Storage +  1TB HDD      1
# 1TB HDD +  1TB HDD                 1
# 32GB HDD                           1
# 64GB SSD                           1
# 128GB HDD                          1
# 240GB SSD                          1
# 8GB SSD                            1
# 508GB Hybrid                       1
# 1.0TB HDD                          1
# 512GB SSD +  1.0TB Hybrid          1
# 256GB SSD +  1.0TB Hybrid          1
# Name: count, dtype: int64

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')
new = df["Memory"].str.split("+", n = 1, expand = True)

df["first"]= new[0]
df["first"]=df["first"].str.strip()

df["second"]= new[1]

df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['first'] = df['first'].str.extract(r'(\d+)', expand=False)

df["second"].fillna("0", inplace = True)

df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['second'] = df['second'].str.extract(r'(\d+)', expand=False)

df["first"] = df["first"].astype(int)
df["second"] = df["second"].astype(int)

df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
df["SSD"]=(df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])
df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
df["Flash_Storage"]=(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])

df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\ankit\AppData\Local\Temp\ipykernel_27872\1392811064.py:1: SyntaxWarning: invalid escape sequence '\.'
#   df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
# C:\Users\ankit\AppData\Local\Temp\ipykernel_27872\1392811064.py:18: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["second"].fillna("0", inplace = True)

# %%
df.sample(10)
# Out:
#     Company   TypeName  Ram               Memory                      Gpu  \
# 807      HP   Notebook    8             2000 HDD   AMD Radeon R7 Graphics
# 245    Dell   Notebook    8  128 SSD +  2000 HDD           AMD Radeon 530
# 189    Dell   Notebook    8  128 SSD +  1000 HDD           AMD Radeon 530
# 650    Asus     Gaming   32              512 SSD  Nvidia GeForce GTX 1080
# 254    Acer   Notebook    4              256 SSD     Nvidia GeForce MX130
# 789    Dell     Gaming    8              256 SSD  Nvidia GeForce GTX 1050
# 58      MSI     Gaming   16  256 SSD +  2000 HDD  Nvidia GeForce GTX 1070
# 473    Dell  Ultrabook    8              256 SSD   Intel UHD Graphics 620
# 256      HP   Notebook    8              128 SSD   AMD Radeon R4 Graphics
# 513    Dell   Notebook   16  256 SSD +  2000 HDD           AMD Radeon 530
#
#           OpSys  Weight        Price  Touchscreen  Ips  Width         ppi  \
# 807  Windows 10    2.04   33513.1200            0    0   1366  100.454670
# 245  Windows 10    2.20   52480.8000            0    0   1920  141.211998
# 189  Windows 10    2.80   57808.8000            0    0   1920  127.335675
# 650  Windows 10    3.80  149130.7200            0    1   1920  127.335675
# 254  Windows 10    3.00   37402.5600            0    1   1920  127.335675
# 789  Windows 10    2.62   52480.8000            0    0   1920  141.211998
# 58   Windows 10    2.43  130482.7200            0    0   1920  127.335675
# 473  Windows 10    1.42   98133.7680            1    0   1920  165.632118
# 256  Windows 10    1.91   23757.5520            0    0   1366  100.454670
# 513  Windows 10    2.20   64961.1072            0    0   1920  141.211998
#
#          Cpu brand   HDD  SSD  Hybrid  Flash_Storage
# 807  AMD Processor  2000    0       0              0
# 245  Intel Core i7  2000  128       0              0
# 189  Intel Core i7  1000  128       0              0
# 650  Intel Core i7     0  512       0              0
# 254  Intel Core i3     0  256       0              0
# 789  Intel Core i5     0  256       0              0
# 58   Intel Core i7  2000  256       0              0
# 473  Intel Core i5     0  256       0              0
# 256  AMD Processor     0  128       0              0
# 513  Intel Core i7  2000  256       0              0

# %%
df.drop(columns=['Memory'],inplace=True)

# %%
df.select_dtypes(include='number').corr()['Price']
# Out:
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# Touchscreen      0.191226
# Ips              0.252208
# Width            0.083832
# ppi              0.473487
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
df.drop(columns=['Hybrid','Flash_Storage'],inplace=True)

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df['Gpu brand'] = df['Gpu'].apply(lambda x:x.split()[0])

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips  Width         ppi      Cpu brand  HDD  SSD  \
# 0   71378.6832            0    1   2560  226.983005  Intel Core i5    0  128
# 1   47895.5232            0    0   1440  127.677940  Intel Core i5    0    0
# 2   30636.0000            0    0   1920  141.211998  Intel Core i5    0  256
# 3  135195.3360            0    1   2880  220.534624  Intel Core i7    0  512
# 4   96095.8080            0    1   2560  226.983005  Intel Core i5    0  256
#
#   Gpu brand
# 0     Intel
# 1     Intel
# 2     Intel
# 3       AMD
# 4     Intel

# %%
df['Gpu brand'].value_counts()
# Out:
# Gpu brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
df = df[df['Gpu brand'] != 'ARM']

# %%
df['Gpu brand'].value_counts()
# Out:
# Gpu brand
# Intel     722
# Nvidia    400
# AMD       180
# Name: count, dtype: int64

# %%
sns.barplot(x=df['Gpu brand'],y=df['Price'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Gpu'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  Ips  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#    Width         ppi      Cpu brand  HDD  SSD Gpu brand
# 0   2560  226.983005  Intel Core i5    0  128     Intel
# 1   1440  127.677940  Intel Core i5    0    0     Intel
# 2   1920  141.211998  Intel Core i5    0  256     Intel
# 3   2880  220.534624  Intel Core i7    0  512       AMD
# 4   2560  226.983005  Intel Core i5    0  256     Intel

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
sns.barplot(x=df['OpSys'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
df['os'] = df['OpSys'].apply(cat_os)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  Ips  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#    Width         ppi      Cpu brand  HDD  SSD Gpu brand                  os
# 0   2560  226.983005  Intel Core i5    0  128     Intel                 Mac
# 1   1440  127.677940  Intel Core i5    0    0     Intel                 Mac
# 2   1920  141.211998  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3   2880  220.534624  Intel Core i7    0  512       AMD                 Mac
# 4   2560  226.983005  Intel Core i5    0  256     Intel                 Mac

# %%
df.drop(columns=['OpSys'],inplace=True)

# %%
sns.barplot(x=df['os'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df['Weight'])
# Out:
# C:\Users\ankit\AppData\Local\Temp\ipykernel_27872\1125578356.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Weight'])
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sns.scatterplot(x=df['Weight'],y=df['Price'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
df.select_dtypes(include='number').corr()['Price']
# Out:
# Ram            0.742905
# Weight         0.209867
# Price          1.000000
# Touchscreen    0.192917
# Ips            0.253320
# Width          0.084590
# ppi            0.475368
# HDD           -0.096891
# SSD            0.670660
# Name: Price, dtype: float64

# %%
sns.distplot(np.log(df['Price']))
# Out:
# C:\Users\ankit\AppData\Local\Temp\ipykernel_27872\3556049916.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price']))
# <Axes: xlabel='Price', ylabel='Density'>

# %%
X = df.drop(columns=['Price'])
y = np.log(df['Price'])

# %%
X
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  Ips  Width  \
# 0      Apple           Ultrabook    8    1.37            0    1   2560
# 1      Apple           Ultrabook    8    1.34            0    0   1440
# 2         HP            Notebook    8    1.86            0    0   1920
# 3      Apple           Ultrabook   16    1.83            0    1   2880
# 4      Apple           Ultrabook    8    1.37            0    1   2560
# ...      ...                 ...  ...     ...          ...  ...    ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1    1   1920
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1    1   3200
# 1300  Lenovo            Notebook    2    1.50            0    0   1366
# 1301      HP            Notebook    6    2.19            0    0   1366
# 1302    Asus            Notebook    4    2.20            0    0   1366
#
#              ppi              Cpu brand   HDD  SSD Gpu brand  \
# 0     226.983005          Intel Core i5     0  128     Intel
# 1     127.677940          Intel Core i5     0    0     Intel
# 2     141.211998          Intel Core i5     0  256     Intel
# 3     220.534624          Intel Core i7     0  512       AMD
# 4     226.983005          Intel Core i5     0  256     Intel
# ...          ...                    ...   ...  ...       ...
# 1298  157.350512          Intel Core i7     0  128     Intel
# 1299  276.053530          Intel Core i7     0  512     Intel
# 1300  111.935204  Other Intel Processor     0    0     Intel
# 1301  100.454670          Intel Core i7  1000    0       AMD
# 1302  100.454670  Other Intel Processor   500    0     Intel
#
#                       os
# 0                    Mac
# 1                    Mac
# 2     Others/No OS/Linux
# 3                    Mac
# 4                    Mac
# ...                  ...
# 1298             Windows
# 1299             Windows
# 1300             Windows
# 1301             Windows
# 1302             Windows
#
# [1302 rows x 13 columns]

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

# %%
X_train
# Out:
#       Company            TypeName  Ram  Weight  Touchscreen  Ips  Width  \
# 183   Toshiba            Notebook    8    2.00            0    0   1366
# 1141      MSI              Gaming    8    2.40            0    0   1920
# 1049     Asus             Netbook    4    1.20            0    0   1366
# 1020     Dell  2 in 1 Convertible    4    2.08            1    1   1920
# 878      Dell            Notebook    4    2.18            0    0   1920
# ...       ...                 ...  ...     ...          ...  ...    ...
# 466      Acer            Notebook    4    2.20            0    0   1366
# 299      Asus           Ultrabook   16    1.63            0    0   1920
# 493      Acer            Notebook    8    2.20            0    0   1366
# 527    Lenovo            Notebook    8    2.20            0    0   1366
# 1193    Apple           Ultrabook    8    0.92            0    1   2304
#
#              ppi              Cpu brand   HDD  SSD Gpu brand  \
# 183   100.454670          Intel Core i5     0  128     Intel
# 1141  141.211998          Intel Core i7  1000  128    Nvidia
# 1049  135.094211  Other Intel Processor     0    0     Intel
# 1020  141.211998          Intel Core i3  1000    0     Intel
# 878   141.211998          Intel Core i5  1000  128    Nvidia
# ...          ...                    ...   ...  ...       ...
# 466   100.454670          Intel Core i3   500    0    Nvidia
# 299   141.211998          Intel Core i7     0  512    Nvidia
# 493   100.454670          AMD Processor  1000    0       AMD
# 527   100.454670          Intel Core i3  2000    0    Nvidia
# 1193  226.415547  Other Intel Processor     0    0     Intel
#
#                       os
# 183              Windows
# 1141             Windows
# 1049  Others/No OS/Linux
# 1020             Windows
# 878              Windows
# ...                  ...
# 466              Windows
# 299              Windows
# 493              Windows
# 527   Others/No OS/Linux
# 1193                 Mac
#
# [1106 rows x 13 columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,8,11,12])
],remainder='passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8018514990756
# MAE 0.2118717858531953

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,8,11,12])
],remainder='passthrough')

step2 = Ridge(alpha=10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.808988715679785
# MAE 0.21056906214922616

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,8,11,12])
],remainder='passthrough')

step2 = Lasso(alpha=0.001)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8028700097435543
# MAE 0.2126263615436257

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,8,11,12])
],remainder='passthrough')

step2 = KNeighborsRegressor(n_neighbors=3)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7950981951152319
# MAE 0.19680509151401596

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,8,11,12])
],remainder='passthrough')

step2 = DecisionTreeRegressor(max_depth=8)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8488854062623435
# MAE 0.1785915158471723

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,8,11,12])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8851220515605964
# MAE 0.16095842212620742

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,8,11,12])
],remainder='passthrough')

step2 = AdaBoostRegressor(n_estimators=15,learning_rate=1.0)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7858883628586204
# MAE 0.23462090962840204

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,8,11,12])
],remainder='passthrough')

step2 = GradientBoostingRegressor(n_estimators=500)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8813521505812278
# MAE 0.15833454204857067

# %%
from sklearn.ensemble import VotingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,8,11,12])
],remainder='passthrough')


rf = RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15)
gbdt = GradientBoostingRegressor(n_estimators=100,max_features=0.5)
clf = DecisionTreeRegressor(max_depth=8)
step2 = VotingRegressor([('rf', rf), ('gbdt', gbdt), ('clf',clf),],weights=[5,1,1])

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8867421366253301
# MAE 0.15934371298178984

# %%
import joblib

joblib.dump(df,open('df.pkl','wb'))
joblib.dump(pipe,open('pipe.pkl','wb'))

# %%
df
# Out:
#      Company            TypeName  Ram  Weight        Price  Touchscreen  Ips  \
# 0      Apple           Ultrabook    8    1.37   71378.6832            0    1
# 1      Apple           Ultrabook    8    1.34   47895.5232            0    0
# 2         HP            Notebook    8    1.86   30636.0000            0    0
# 3      Apple           Ultrabook   16    1.83  135195.3360            0    1
# 4      Apple           Ultrabook    8    1.37   96095.8080            0    1
# ...      ...                 ...  ...     ...          ...          ...  ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80   33992.6400            1    1
# 1299  Lenovo  2 in 1 Convertible   16    1.30   79866.7200            1    1
# 1300  Lenovo            Notebook    2    1.50   12201.1200            0    0
# 1301      HP            Notebook    6    2.19   40705.9200            0    0
# 1302    Asus            Notebook    4    2.20   19660.3200            0    0
#
#       Width         ppi              Cpu brand   HDD  SSD Gpu brand  \
# 0      2560  226.983005          Intel Core i5     0  128     Intel
# 1      1440  127.677940          Intel Core i5     0    0     Intel
# 2      1920  141.211998          Intel Core i5     0  256     Intel
# 3      2880  220.534624          Intel Core i7     0  512       AMD
# 4      2560  226.983005          Intel Core i5     0  256     Intel
# ...     ...         ...                    ...   ...  ...       ...
# 1298   1920  157.350512          Intel Core i7     0  128     Intel
# 1299   3200  276.053530          Intel Core i7     0  512     Intel
# 1300   1366  111.935204  Other Intel Processor     0    0     Intel
# 1301   1366  100.454670          Intel Core i7  1000    0       AMD
# 1302   1366  100.454670  Other Intel Processor   500    0     Intel
#
#                       os
# 0                    Mac
# 1                    Mac
# 2     Others/No OS/Linux
# 3                    Mac
# 4                    Mac
# ...                  ...
# 1298             Windows
# 1299             Windows
# 1300             Windows
# 1301             Windows
# 1302             Windows
#
# [1302 rows x 14 columns]
